# %% [markdown]
# ### Ternary Operators
# #### Known as conditional expressions are operators that evaluate something based on a condition  and test a condition in  one line instead of the multiline if-else

# %%
a = 50
b = 45 


if (a > b):
    max = a
    print("a is greater than b")
    print(f"max = {max}")
    
    
max = a if (a > b) else b
print(f"max = {max}")   


i = 25
j = 25
are_equal = True if (i == j) else False
print(f"are_equal = {are_equal}")


l = 25
m = 25
are_equal = True if (l >= m) else False
print(f"are_equal = {are_equal}")
# Out:
# a is greater than b
# max = 50
# max = 50
# are_equal = True
# are_equal = True

# %%
f = 11

is_even = True if (f % 2 == 0) else False
print(f"is_even = {is_even}")
# Out:
# is_even = False
