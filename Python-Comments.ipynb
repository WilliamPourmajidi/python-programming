# %%
# comments are not executed
# these are notes for Human rather than machines! 

print("This is another command that will be executed! Below comments are exculded from execution.")

"""
This is a multiple line comment -- Appraoch #1
print("Hello")
print("Hello World, second line!")
print("Hello World, third line!")
print("Hello World, fourth line!")
print("Hello World, fifth line!")
"""
 
# This is a multiple line comment -- Appraoch #2
# print("Hello")
# print("Hello World, second line!")
# print("Hello World, third line!")
# print("Hello World, fourth line!")
# print("Hello World, fifth line!")

print("This is another command that will be executed! Above comments are exculded from execution.")
print("-----------------------------------")
# Out:
# This is another command that will be executed! Below comments are exculded from execution.
# This is another command that will be executed! Anove comments are exculded from execution.
# -----------------------------------
